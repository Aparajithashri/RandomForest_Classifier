# %% [markdown]
# <a href="https://colab.research.google.com/github/Aparajithashri/RandomForest_Classifier/blob/main/Predict_the_importance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Predict the importance of case

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
data = pd.read_excel('train.xlsx')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8878 entries, 0 to 8877
# Columns: 328 entries, appno to importance
# dtypes: bool(1), datetime64[ns](4), float64(1), int64(276), object(46)
# memory usage: 22.2+ MB

# %%
data.columns
# Out:
# Index(['appno', 'application', 'country.alpha2', 'country.name',
#        'decisiondate', 'docname', 'doctypebranch', 'ecli', 'introductiondate',
#        'issue.0',
#        ...
#        'ccl_article=6', 'ccl_article=7', 'ccl_article=8', 'ccl_article=9',
#        'ccl_article=p1', 'ccl_article=p12', 'ccl_article=p4', 'ccl_article=p6',
#        'ccl_article=p7', 'importance'],
#       dtype='object', length=328)

# %%
data.set_index("appno", inplace = True)
data.head
# Out:
# <bound method NDFrame.head of          application country.alpha2  ... ccl_article=p7 importance
# appno                                ...
# 34783/06     MS WORD             al  ...              0          4
# 12878/10     MS WORD             al  ...              0          4
# 54268/00     MS WORD             al  ...              0          2
# 5250/07      MS WORD             al  ...              0          4
# 40430/08     MS WORD             al  ...              0          4
# ...              ...            ...  ...            ...        ...
# 45245/15     MS WORD             gb  ...              0          3
# 39360/98     MS WORD             gb  ...              0          3
# 34575/04     MS WORD             gb  ...              0          2
# 39482/98     MS WORD             gb  ...              0          1
# 63701/00     MS WORD             gb  ...              0          4
#
# [8878 rows x 327 columns]>

# %%
data.drop(['application','judgementdate','kpdate','docname','country.alpha2','country.name','ecli','languageisocode','itemid','originatingbody','originatingbody_name','originatingbody_type','respondent.0','parties.0','parties.1','parties.2','respondent.1','respondent.2','respondent.3','respondent.4','respondentOrderEng','separateopinion','sharepointid','typedescription','decisiondate','introductiondate'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8878 entries, 34783/06 to 63701/00
# Columns: 301 entries, doctypebranch to importance
# dtypes: float64(1), int64(272), object(28)
# memory usage: 20.5+ MB

# %%
data.select_dtypes(object)
# Out:
#          doctypebranch  ... issue.9
# appno                   ...
# 34783/06       CHAMBER  ...      -1
# 12878/10     COMMITTEE  ...      -1
# 54268/00       CHAMBER  ...      -1
# 5250/07        CHAMBER  ...      -1
# 40430/08     COMMITTEE  ...      -1
# ...                ...  ...     ...
# 45245/15       CHAMBER  ...      -1
# 39360/98       CHAMBER  ...      -1
# 34575/04       CHAMBER  ...      -1
# 39482/98       CHAMBER  ...      -1
# 63701/00       CHAMBER  ...      -1
#
# [8878 rows x 28 columns]

# %%
data.shape
# Out:
# (8878, 301)

# %%
y = data['importance']
data.drop(['importance'],axis=1,inplace=True)

# %%
data.fillna(-1,inplace=True)
data.fillna('NaN')
# Out:
#          doctypebranch  ... ccl_article=p7
# appno                   ...
# 34783/06       CHAMBER  ...              0
# 12878/10     COMMITTEE  ...              0
# 54268/00       CHAMBER  ...              0
# 5250/07        CHAMBER  ...              0
# 40430/08     COMMITTEE  ...              0
# ...                ...  ...            ...
# 45245/15       CHAMBER  ...              0
# 39360/98       CHAMBER  ...              0
# 34575/04       CHAMBER  ...              0
# 39482/98       CHAMBER  ...              0
# 63701/00       CHAMBER  ...              0
#
# [8878 rows x 300 columns]

# %%
data.isnull()
# Out:
#           doctypebranch  issue.0  ...  ccl_article=p6  ccl_article=p7
# appno                             ...
# 34783/06          False    False  ...           False           False
# 12878/10          False    False  ...           False           False
# 54268/00          False    False  ...           False           False
# 5250/07           False    False  ...           False           False
# 40430/08          False    False  ...           False           False
# ...                 ...      ...  ...             ...             ...
# 45245/15          False    False  ...           False           False
# 39360/98          False    False  ...           False           False
# 34575/04          False    False  ...           False           False
# 39482/98          False    False  ...           False           False
# 63701/00          False    False  ...           False           False
#
# [8878 rows x 300 columns]

# %%
data.drop(['doctypebranch','issue.0','issue.2','issue.1','issue.10','issue.11','issue.12','issue.13','issue.14','issue.15','issue.16','issue.17','issue.18','issue.19','issue.20','issue.21','issue.22','issue.23','issue.24','issue.25','issue.26','issue.3','issue.4','issue.5','issue.6','issue.7','issue.8','issue.9'],axis=1,inplace=True)

# %%
data.head(5)
# Out:
#           rank  article=3  ...  ccl_article=p6  ccl_article=p7
# appno                      ...
# 34783/06  1067          0  ...               0               0
# 12878/10  1668          0  ...               0               0
# 54268/00   506          0  ...               0               0
# 5250/07   1448          0  ...               0               0
# 40430/08  1119          0  ...               0               0
#
# [5 rows x 272 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(data, y)
print(x_train.shape)
print(y_train.shape)
# Out:
# (6658, 272)
# (6658,)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8878 entries, 34783/06 to 63701/00
# Columns: 272 entries, rank to ccl_article=p7
# dtypes: int64(272)
# memory usage: 18.8+ MB

# %%
# one-hot encode input variables
onehot_encoder = OneHotEncoder()
onehot_encoder.fit(x)
X_train = onehot_encoder.transform(x_train)
X_test = onehot_encoder.transform(x_test)
# ordinal encode target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators = 500, max_depth = 6)
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=6, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
pred = clf.predict(x_test)
print("Accuracy",accuracy_score(y_test,pred)*100)
# Out:
# Accuracy 78.1981981981982

# %% [markdown]
# ##Got Accuracy 78.19

# %% [markdown]
# #Testing

# %%
test = pd.read_csv('test.csv')
# Out:
#          appno application  ... ccl_article=p6 ccl_article=p7
# 0      1194/04     MS WORD  ...              0              0
# 1     53865/11     MS WORD  ...              0              0
# 2     43838/07     MS WORD  ...              0              0
# 3     11157/04     MS WORD  ...              0              0
# 4     42443/02     MS WORD  ...              0              0
# ...        ...         ...  ...            ...            ...
# 4755   4345/06     MS WORD  ...              0              0
# 4756  10761/09     MS WORD  ...              0              0
# 4757    805/09     MS WORD  ...              0              0
# 4758  44711/16     MS WORD  ...              0              0
# 4759  21155/18     MS WORD  ...              0              0
#
# [4760 rows x 327 columns]
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4760 entries, 0 to 4759
# Columns: 327 entries, appno to ccl_article=p7
# dtypes: bool(1), float64(5), int64(275), object(46)
# memory usage: 11.8+ MB

# %%
#Drop unwanted columns
test.drop(['doctypebranch','issue.2','issue.0','judgementdate','kpdate','docname','issue.1','issue.10','issue.11','issue.12','issue.13','issue.14','issue.15','issue.16','issue.17','issue.18','issue.19','issue.20','issue.21','issue.22','issue.23','issue.24','issue.25','issue.26','issue.3','issue.4','issue.5','issue.6','issue.7','issue.8','issue.9','application','country.alpha2','country.name','ecli','languageisocode','itemid','originatingbody','originatingbody_name','originatingbody_type','respondent.0','parties.0','parties.1','parties.2','respondent.1','respondent.2','respondent.3','respondent.4','respondentOrderEng','separateopinion','sharepointid','typedescription','decisiondate','introductiondate'],axis=1,inplace=True)

# %%
app = test[['appno']]
answer = pd.DataFrame(app)
test.drop(['appno'],axis=1,inplace=True)

# %%
test['rank'] = test['rank'].astype('int64') 

test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4760 entries, 0 to 4759
# Columns: 272 entries, rank to ccl_article=p7
# dtypes: int64(272)
# memory usage: 9.9 MB

# %%
#Predict

answer['importance'] = clf.predict(test)
answer.head(10)
# Out:
#       appno  importance
# 0   1194/04           4
# 1  53865/11           4
# 2  43838/07           4
# 3  11157/04           3
# 4  42443/02           4
# 5   5351/04           4
# 6  10493/12           4
# 7  60805/00           4
# 8  19127/06           4
# 9  23929/08           4

# %%
# saving the dataframe 
answer.to_csv('Submission.csv')

# %%
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
writer = ExcelWriter('Submission.xlsx')
answer.to_excel(writer,'Sheet1',index=False)
writer.save()
